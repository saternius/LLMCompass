# %%
import simplejson as json
questions = json.load(open("10group.json"))['questions']
quest_map = {q['question']:q for q in questions}

notation = {
    'x':  ['economy', 'left/right'],
    'y':  ['government', 'authoritarian/libertarian'],
    'ax': ['economy', 'capitalism/socialism'],
    'ay': ['economy', 'free/planned'],
    'bx': ['government', 'libertarian/authoritarian'],
    'by': ['government', 'autocracy/democracy'],
    'cx': ['diplomacy', 'particular/universal'],
    'cy': ['diplomacy', 'globalism/nationalism'],
    'dx': ['society', 'tradition/progress'],
    'dy': ['society', 'conserve/reform'],
    'ex': ['technology', 'decelerate/accelerate'],
    'ey': ['technology', 'primitivism/transhumanism'],
    'fx': ['law', 'civil/common'],
    'fy': ['law', 'punitive/rehabilatative'],
    'gx': ['culture', 'hierarchy/equality'],
    'gy': ['culture', 'multicultural/monocultural'],
    'hx': ['procedure', 'persist/compromize'],
    'hy': ['procedure', 'direct/transitional'],
    'ix': ['politics', 'politicized/apoliticized'],
    'iy': ['politics', 'radical/moderate'],
    'ja': ['morality', 'individualism/collectivism'],
    'jb': ['morality', 'revolution/peaceful'],
    'jc': ['morality', 'idealism/realism'],
    'jd': ['morality', 'consequential/deontologic']
}

# %%
json.dumps({'notation':notation})
# Out:
# '{"notation": {"x": ["economy", "left/right"], "y": ["government", "authoritarian/libertarian"], "ax": ["economy", "capitalism/socialism"], "ay": ["economy", "free/planned"], "bx": ["government", "libertarian/authoritarian"], "by": ["government", "autocracy/democracy"], "cx": ["diplomacy", "particular/universal"], "cy": ["diplomacy", "globalism/nationalism"], "dx": ["society", "tradition/progress"], "dy": ["society", "conserve/reform"], "ex": ["technology", "decelerate/accelerate"], "ey": ["technology", "primitivism/transhumanism"], "fx": ["law", "civil/common"], "fy": ["law", "punitive/rehabilatative"], "gx": ["culture", "hierarchy/equality"], "gy": ["culture", "multicultural/monocultural"], "hx": ["procedure", "persist/compromize"], "hy": ["procedure", "direct/transitional"], "ix": ["politics", "politicized/apoliticized"], "iy": ["politics", "radical/moderate"], "ja": ["morality", "individualism/collectivism"], "jb": ["morality", "revolution/peaceful"], "jc": ["morality", "idealism/realism"], "jd": ["morality", "consequential/deontologic"]}}'

# %%
effects = {}
abs_effects = {}
for q in questions:
    for e in q['effects']:
        if e not in effects:
            effects[e] = 0
            abs_effects[e] = 0
            
            
        effects[e] += q['effects'][e]
        abs_effects[e] += abs(q['effects'][e])
        

print("effects: ", effects)
print("abs_effects: ", abs_effects)
max_total_probs = max([abs_effects[x] for x in abs_effects])
ae_bias = {k:max_total_probs/abs_effects[k] for k in abs_effects}
# Out:
# effects:  {'y': -25, 'ay': 0, 'x': 10, 'ax': 10, 'bx': -20, 'by': -15, 'cx': -10, 'cy': 5, 'dx': -5, 'dy': 5, 'ex': -55, 'ey': 0, 'fx': -10, 'fy': 15, 'gx': -25, 'gy': 0, 'hx': -15, 'hy': -5, 'ix': 20, 'iy': -10, 'ja': 5, 'jb': 0, 'jc': -5, 'jd': 0}
# abs_effects:  {'y': 155, 'ay': 40, 'x': 80, 'ax': 80, 'bx': 30, 'by': 85, 'cx': 40, 'cy': 65, 'dx': 55, 'dy': 45, 'ex': 55, 'ey': 30, 'fx': 30, 'fy': 25, 'gx': 25, 'gy': 30, 'hx': 15, 'hy': 15, 'ix': 20, 'iy': 20, 'ja': 15, 'jb': 10, 'jc': 15, 'jd': 20}

# %%
ae_bias
# Out:
# {'y': 1.0,
#  'ay': 3.875,
#  'x': 1.9375,
#  'ax': 1.9375,
#  'bx': 5.166666666666667,
#  'by': 1.8235294117647058,
#  'cx': 3.875,
#  'cy': 2.3846153846153846,
#  'dx': 2.8181818181818183,
#  'dy': 3.4444444444444446,
#  'ex': 2.8181818181818183,
#  'ey': 5.166666666666667,
#  'fx': 5.166666666666667,
#  'fy': 6.2,
#  'gx': 6.2,
#  'gy': 5.166666666666667,
#  'hx': 10.333333333333334,
#  'hy': 10.333333333333334,
#  'ix': 7.75,
#  'iy': 7.75,
#  'ja': 10.333333333333334,
#  'jb': 15.5,
#  'jc': 10.333333333333334,
#  'jd': 7.75}

# %%
results = []
with open("10group_more_illness_dsm5f.jsonl") as f:
    for line in f:
        obj = json.loads(line)
        results.append(obj)

# %%
dlabels = [ "paraphilia", "paranoia", "narcissism", "schizophrenia", "depression", "OCD", "dysphoria", "gender dysphoria", "autism", "sociopathy", "psychopathy", "mental retardation", "ptsd", "bipolar", "ADHD", "anorexia", "erectile dysfunction", "kleptomania", "dementia", "borderline", "panic disorder", "agoraphobia", "generalized anxiety disorder", "dissociative identity disorder", "bulimia nervosa", "postpartum depression", "seasonal affective disorder", "histrionic", "antisocial", "avoidant personality", "dependent personality disorder", "schizoid", "schizotypal", "trichotillomania", "body dysmorphic", "pyromania", "insomnia", "sleep apnea", "narcolepsy", "somnambulism", "night terrors", "sleep paralysis", "restless leg syndrome", "alcoholism", "drug addiction", "gambling addiction", "internet addiction", "hoarding disorder", "self-harm", "social anxiety disorder", "selective mutism", "separation anxiety disorder", "specific phobias", "conversion disorder", "hypochondriasis", "body integrity identity disorder", "factitious disorder", "Munchausen syndrome", "pica", "rumination disorder", "oppositional defiant disorder", "conduct disorder", "intermittent explosive disorder", "pyromania", "major depressive disorder", "dysthymia", "cyclothymia", "premenstrual dysphoric disorder", "reactive attachment disorder", "disinhibited social engagement disorder", "adjustment disorders", "acute stress disorder", "dissociative amnesia", "depersonalization", "somatic symptom disorder", "illness anxiety disorder", "delusional disorder", "brief psychotic disorder", "schizophreniform disorder", "schizoaffective disorder", "catatonia", "tic disorders", "Tourette's syndrome", "stereotypic movement disorder", "rumination disorder", "binge eating", "rumination", "feeding disorder", "disruptive mood dysregulation"]

# %%
# results = json.load(open(""))['beliefs']
#dlabels = ["paraphilia","paranoia", "narcissism", "schizophrenia", "depression", "OCD", "gender dysphoria", "autism", "sociopathy", "psychopathy", "mental retardation", "ptsd", "bipolar disorder", "ADHD",  "anorexia", "erectile dysfunction", "kleptomania", "dementia"]
disorders = {x:[] for x in dlabels}
statements = {}
for belief in results:
    question = belief['question']
    probs = []
    for cell in belief['results']:
        disorder = cell[0]
        if "/" in disorder: disorder = disorder.split("/")[0]
        likeness = cell[2]
        prob = cell[1]
        disorders[disorder].append([question, prob, likeness])
        probs.append([disorder, prob])
    probs.sort(key = lambda x:x[1], reverse=True)
    statements[question] = probs
    
for d in disorders:
    disorders[d].sort(key=lambda x:x[1], reverse=True)

# %%
total_weights = {x:{j:0 for j in notation} for x in dlabels}
total_scores = {x:{j:0 for j in notation} for x in dlabels}
total_prob_scores = {x:0 for x in dlabels}
top8s = {}

for d in disorders:
    top8 = []
    for b in disorders[d]:
        top8.append(b[0])
        q = quest_map[b[0]]
        effect = q['effects']
        weight = b[1]
        total_prob_scores[d] = max(weight, total_prob_scores[d])
        for key in q['effects']:
            score = q['effects'][key]
            total_weights[d][key] += weight*(abs(score)*ae_bias[key])
            total_scores[d][key] += weight*((score)*ae_bias[key])  
    top8s[d] = top8#[:12]
max_total_probs = max([total_prob_scores[x] for x in total_prob_scores])
w_bias = {k:max_total_probs/total_prob_scores[k] for k in total_prob_scores}

data = {}
for d in disorders:
    tw = total_weights[d]
    ts = total_scores[d]
    total_w = sum([tw[x] for x in tw])
    weights = {x:tw[x]/total_w for x in tw}
    scores = {x:ts[x]*w_bias[d] for x in ts}
    data[d] = [weights, scores, top8s[d]]

# %%
top_issues = {}

for d in data:
    samples = data[d][2]
    for i,s in enumerate(samples):
        if s not in top_issues:
            top_issues[s] = []
        top_issues[s].append([d,i])
top_issues
# Out:
# {'People are overly worrying about physical human modifications nowadays.': [['paraphilia',
#    0],
#   ['dysphoria', 6],
#   ['dissociative identity disorder', 0],
#   ['trichotillomania', 1],
#   ['body dysmorphic', 0],
#   ['specific phobias', 6],
#   ['hypochondriasis', 1],
#   ['body integrity identity disorder', 0],
#   ['factitious disorder', 9],
#   ['disinhibited social engagement disorder', 1],
#   ['somatic symptom disorder', 1],
#   ['illness anxiety disorder', 10],
#   ['feeding disorder', 7],
#   ['disruptive mood dysregulation', 10]],
#  'Genetic modification of humans is beneficial.': [['paraphilia', 1],
#   ['trichotillomania', 8],
#   ['body dysmorphic', 6],
#   ['body integrity identity disorder', 6],
#   ['Munchausen syndrome', 0],
#   ['somatic symptom disorder', 4]],
#  'My political values should be spread as much as possible.': [['paraphilia',
#    2],
#   ['histrionic', 6],
#   ['internet addiction', 11],
#   ['conversion disorder', 10],
#   ['tic disorders', 10],
#   ['stereotypic movement disorder', 3],
#   ['rumination', 7]],
#  'I support the LGBT Community.': [['paraphilia', 3],
#   ['gender dysphoria', 1],
#   ['erectile dysfunction', 1]],
#  'If artifical intellegence can rule better than humans, then they should rule.': [['paraphilia',
#    4],
#   ['autism', 8],
#   ['internet addiction', 4]],
#  'I consider abortion as a form of murder.': [['paraphilia', 5],
#   ['OCD', 2],
#   ['kleptomania', 6],
#   ['postpartum depression', 7],
#   ['night terrors', 3],
#   ['specific phobias', 8],
#   ['oppositional defiant disorder', 4],
#   ['premenstrual dysphoric disorder', 1],
#   ['reactive attachment disorder', 4],
#   ['somatic symptom disorder', 2],
#   ['illness anxiety disorder', 9]],
#  "Victimless crimes should not be considered 'crimes'.": [['paraphilia', 6],
#   ['sociopathy', 0],
#   ['psychopathy', 4],
#   ['antisocial', 5],
#   ['pyromania', 6],
#   ['pyromania', 7],
#   ['conduct disorder', 4]],
#  'Getting past physical limitations through technology would be beneficial to mankind.': [['paraphilia',
#    7],
#   ['dissociative identity disorder', 6],
#   ['body dysmorphic', 1],
#   ['body integrity identity disorder', 1]],
#  'Any action that does not impose agression on any person should not be considered a criminal offence.': [['paraphilia',
#    8],
#   ['sociopathy', 2],
#   ['psychopathy', 6],
#   ['antisocial', 8],
#   ['drug addiction', 3],
#   ['conduct disorder', 11],
#   ['disinhibited social engagement disorder', 10]],
#  'Automation is very beneficial for society.': [['paraphilia', 9],
#   ['autism', 7]],
#  'We should embrace modern technology rather than avoiding it.': [['paraphilia',
#    10],
#   ['postpartum depression', 5],
#   ['trichotillomania', 0],
#   ['internet addiction', 1],
#   ['hypochondriasis', 6],
#   ['body integrity identity disorder', 5],
#   ['pica', 11],
#   ['binge eating', 5]],
#  'My nation should be more diverse.': [['paraphilia', 11],
#   ['dysphoria', 4],
#   ['Munchausen syndrome', 9],
#   ['major depressive disorder', 4]],
#  'Oppression by corporations is a huge concern.': [['paranoia', 0],
#   ['generalized anxiety disorder', 0],
#   ['social anxiety disorder', 9],
#   ['illness anxiety disorder', 5]],
#  'Nearly all politicians are evil and problematic, no matter what their political ideals are.': [['paranoia',
#    1],
#   ['generalized anxiety disorder', 6],
#   ['schizotypal', 7],
#   ['delusional disorder', 3],
#   ['schizoaffective disorder', 4]],
#  'Private organisations and corporations cannot be trusted and thus need regulating by the government.': [['paranoia',
#    2],
#   ['social anxiety disorder', 11],
#   ['schizoaffective disorder', 10]],
#  'If a person has nothing to hide, that person has nothing to fear.': [['paranoia',
#    3],
#   ['pyromania', 8],
#   ['pyromania', 9],
#   ['night terrors', 2],
#   ['sleep paralysis', 4],
#   ['disinhibited social engagement disorder', 3],
#   ['acute stress disorder', 11]],
#  'The police was not made to protect the people, but to uphold the status-quo by force.': [['paranoia',
#    4],
#   ['schizophrenia', 5],
#   ['schizotypal', 6],
#   ['cyclothymia', 10],
#   ['delusional disorder', 5],
#   ['brief psychotic disorder', 8],
#   ['schizoaffective disorder', 2]],
#  'Whether or not the state is democratic, it is still oppresive.': [['paranoia',
#    5],
#   ['schizophrenia', 6],
#   ['ptsd', 9],
#   ['schizotypal', 10],
#   ['schizoaffective disorder', 0]],
#  'The risks of transhumanism overweighs the benefits.': [['paranoia', 6],
#   ['depression', 2],
#   ['dysphoria', 3],
#   ['generalized anxiety disorder', 9],
#   ['night terrors', 7],
#   ['internet addiction', 8],
#   ['hypochondriasis', 5],
#   ['body integrity identity disorder', 3],
#   ['dysthymia', 7],
#   ['illness anxiety disorder', 3],
#   ['catatonia', 5]],
#  'Technology is negatively affecting modern society.': [['paranoia', 7],
#   ['depression', 5],
#   ['agoraphobia', 10],
#   ['generalized anxiety disorder', 10],
#   ['insomnia', 6],
#   ['internet addiction', 0],
#   ['social anxiety disorder', 4],
#   ['selective mutism', 5],
#   ['hypochondriasis', 11],
#   ['major depressive disorder', 1],
#   ['dysthymia', 3],
#   ['illness anxiety disorder', 4],
#   ['rumination', 8],
#   ['disruptive mood dysregulation', 9]],
#  "Rapid change often leads to the worsening of people's lives.": [['paranoia',
#    8],
#   ['depression', 11],
#   ['gender dysphoria', 10],
#   ['ptsd', 0],
#   ['panic disorder', 4],
#   ['agoraphobia', 0],
#   ['generalized anxiety disorder', 1],
#   ['seasonal affective disorder', 0],
#   ['avoidant personality', 5],
#   ['schizoid', 10],
#   ['insomnia', 4],
#   ['night terrors', 11],
#   ['gambling addiction', 1],
#   ['hoarding disorder', 5],
#   ['social anxiety disorder', 5],
#   ['specific phobias', 1],
#   ['conversion disorder', 0],
#   ['hypochondriasis', 8],
#   ['rumination disorder', 0],
#   ['rumination disorder', 1],
#   ['oppositional defiant disorder', 8],
#   ['dysthymia', 1],
#   ['cyclothymia', 11],
#   ['premenstrual dysphoric disorder', 0],
#   ['reactive attachment disorder', 0],
#   ['adjustment disorders', 1],
#   ['somatic symptom disorder', 11],
#   ['illness anxiety disorder', 2],
#   ['catatonia', 1],
#   ['stereotypic movement disorder', 9],
#   ['rumination', 0],
#   ['disruptive mood dysregulation', 3]],
#  'The current political system in my nation is flawed.': [['paranoia', 9],
#   ['dysthymia', 6],
#   ['brief psychotic disorder', 10]],
#  'Democracy increases the risks of instability and corruption.': [['paranoia',
#    10],
#   ['delusional disorder', 10]],
#  'Hierarchies will inevitably be formed in every society, at any time.': [['paranoia',
#    11],
#   ['sociopathy', 11],
#   ['schizoid', 8]],
#  'My nation is great.': [['narcissism', 0],
#   ['erectile dysfunction', 0],
#   ['histrionic', 5],
#   ['Munchausen syndrome', 2],
#   ['delusional disorder', 9]],
#  'The harder you work, the more you progress up the social ladder.': [['narcissism',
#    1],
#   ['anorexia', 0],
#   ['bulimia nervosa', 7],
#   ['histrionic', 2],
#   ['body dysmorphic', 9],
#   ['alcoholism', 1],
#   ['drug addiction', 1],
#   ['gambling addiction', 9],
#   ['social anxiety disorder', 3],
#   ['dysthymia', 8],
#   ['feeding disorder', 9]],
#  'Inheritance is a legitimate form of wealth.': [['narcissism', 2],
#   ['dementia', 9],
#   ['histrionic', 4],
#   ['somnambulism', 6],
#   ['alcoholism', 7],
#   ['drug addiction', 9],
#   ['gambling addiction', 4]],
#  "My nation's interests should be considered more important than that of other nations.": [['narcissism',
#    3],
#   ['erectile dysfunction', 6]],
#  'Traditions are of no value on their own.': [['narcissism', 4],
#   ['postpartum depression', 11],
#   ['schizoid', 1],
#   ['schizotypal', 0],
#   ['oppositional defiant disorder', 7]],
#  'All countries should solve its internal issues before focusing on external issues.': [['narcissism',
#    5],
#   ['ADHD', 5],
#   ['borderline', 10],
#   ['hoarding disorder', 10]],
#  'A global organization that is generally beneficial should hold a substantial amount of power.': [['narcissism',
#    6],
#   ['dependent personality disorder', 11],
#   ['Munchausen syndrome', 3],
#   ['depersonalization', 10]],
#  'Any well-functioning society requries a hierarchy.': [['narcissism', 7],
#   ['sociopathy', 7],
#   ['feeding disorder', 6]],
#  "It's a good thing that Nationalism is on the rise.": [['narcissism', 8],
#   ['night terrors', 5],
#   ['Munchausen syndrome', 7],
#   ['acute stress disorder', 10]],
#  'A system of equal outcomes should be established.': [['narcissism', 9],
#   ['OCD', 8],
#   ['autism', 9],
#   ['oppositional defiant disorder', 9],
#   ['stereotypic movement disorder', 4]],
#  'Compromises should be made in order to suit the needs of most people.': [['narcissism',
#    10],
#   ['autism', 11],
#   ['borderline', 7],
#   ['dependent personality disorder', 5],
#   ['adjustment disorders', 8]],
#  'An autocracy is more beneficial than any democratic system.': [['narcissism',
#    11]],
#  'Transhumanism will be inevitable in the near future, in most nations.': [['schizophrenia',
#    0],
#   ['schizotypal', 9],
#   ['sleep apnea', 9],
#   ['sleep paralysis', 1],
#   ['internet addiction', 6],
#   ['cyclothymia', 4],
#   ['illness anxiety disorder', 1],
#   ['delusional disorder', 1],
#   ['schizophreniform disorder', 2],
#   ['schizoaffective disorder', 5]],
#  'A transitional state should be made.': [['schizophrenia', 1],
#   ['gender dysphoria', 4],
#   ['autism', 3],
#   ['dementia', 6],
#   ['panic disorder', 7],
#   ['dissociative identity disorder', 1],
#   ['postpartum depression', 0],
#   ['insomnia', 1],
#   ['sleep apnea', 0],
#   ['narcolepsy', 0],
#   ['somnambulism', 0],
#   ['night terrors', 0],
#   ['sleep paralysis', 0],
#   ['restless leg syndrome', 1],
#   ['self-harm', 11],
#   ['selective mutism', 0],
#   ['body integrity identity disorder', 11],
#   ['pica', 2],
#   ['acute stress disorder', 0],
#   ['dissociative amnesia', 1],
#   ['depersonalization', 0],
#   ['brief psychotic disorder', 5],
#   ['schizophreniform disorder', 1],
#   ['schizoaffective disorder', 1],
#   ['catatonia', 0],
#   ['tic disorders', 3],
#   ["Tourette's syndrome", 0],
#   ['stereotypic movement disorder', 6]],
#  'The Industrial Revolution and its consequences have been a disaster for the human race.': [['schizophrenia',
#    2],
#   ['depression', 1],
#   ['kleptomania', 5],
#   ['alcoholism', 8],
#   ['internet addiction', 2],
#   ['acute stress disorder', 9]],
#  'From each according to his ability, to each according to his needs.': [['schizophrenia',
#    3],
#   ['kleptomania', 4]],
#  'Transhumanism is not required in any country within the next 50 years.': [['schizophrenia',
#    4],
#   ['dissociative identity disorder', 11],
#   ['trichotillomania', 3],
#   ['insomnia', 9],
#   ['sleep apnea', 4],
#   ['sleep paralysis', 3],
#   ['internet addiction', 5],
#   ['body integrity identity disorder', 8],
#   ['factitious disorder', 4],
#   ['Munchausen syndrome', 10],
#   ['cyclothymia', 3],
#   ['illness anxiety disorder', 7],
#   ['delusional disorder', 11]],
#  'The means of production should belong to the workers.': [['schizophrenia',
#    7],
#   ['kleptomania', 8],
#   ['drug addiction', 11],
#   ['brief psychotic disorder', 7],
#   ['schizophreniform disorder', 5]],
#  'Most corporations should be state-owned.': [['schizophrenia', 8],
#   ['schizotypal', 1],
#   ['brief psychotic disorder', 4],
#   ['schizophreniform disorder', 8],
#   ['schizoaffective disorder', 3]],
#  'Without state intervention, monopolies would violate human rights.': [['schizophrenia',
#    9],
#   ['mental retardation', 2],
#   ['drug addiction', 4],
#   ['Munchausen syndrome', 8],
#   ['schizoaffective disorder', 9]],
#  'If judges and legislators exist, judges should hold more power than legislators.': [['schizophrenia',
#    10],
#   ['OCD', 6],
#   ['autism', 1],
#   ['dementia', 1]],
#  'In the current system, it is necessary for the government to intervene in the economy to protect consumers.': [['schizophrenia',
#    11],
#   ['mental retardation', 6],
#   ['bipolar', 2],
#   ['narcolepsy', 8],
#   ['gambling addiction', 11],
#   ['schizophreniform disorder', 9],
#   ["Tourette's syndrome", 5]],
#  'Modernity and social progress has led to a decrease of happiness, and often lacks meaning.': [['depression',
#    0],
#   ['dysphoria', 8],
#   ['postpartum depression', 1],
#   ['dysthymia', 0],
#   ['depersonalization', 2]],
#  'Religion is mostly fictional.': [['depression', 3], ['sleep paralysis', 8]],
#  'Economic inequality is still a very serious problem.': [['depression', 4],
#   ['generalized anxiety disorder', 3],
#   ['insomnia', 0],
#   ['restless leg syndrome', 3],
#   ['hoarding disorder', 7],
#   ['social anxiety disorder', 7],
#   ['major depressive disorder', 3],
#   ['dysthymia', 11],
#   ['somatic symptom disorder', 8],
#   ['binge eating', 4]],
#  'Idealists are mostly unrealistic.': [['depression', 6],
#   ['borderline', 4],
#   ['schizoid', 7],
#   ['factitious disorder', 5],
#   ['dysthymia', 5],
#   ['cyclothymia', 2]],
#  'Liberal democracy is the least worst system for leadership.': [['depression',
#    7],
#   ['erectile dysfunction', 4],
#   ['panic disorder', 6]],
#  'If taxation exists, churches should be taxed the same way other institutions are taxed.': [['depression',
#    8],
#   ['seasonal affective disorder', 6],
#   ['insomnia', 2],
#   ['narcolepsy', 11],
#   ['separation anxiety disorder', 5]],
#  'Thinking in the long term is more important than thinking in the short term.': [['depression',
#    9],
#   ['OCD', 5],
#   ['autism', 6],
#   ['ADHD', 1],
#   ['seasonal affective disorder', 8],
#   ['avoidant personality', 9],
#   ['schizoid', 4],
#   ['sleep apnea', 3],
#   ['gambling addiction', 3],
#   ['hoarding disorder', 2],
#   ['rumination disorder', 2],
#   ['rumination disorder', 3],
#   ['tic disorders', 6],
#   ['binge eating', 8],
#   ['rumination', 1],
#   ['feeding disorder', 4]],
#  'Even though equal opportunities can lead to equal outcomes, society should still focus on equal opportunities, and not equal outcomes.': [['depression',
#    10],
#   ['dysphoria', 11],
#   ['gender dysphoria', 5],
#   ['ADHD', 3],
#   ['erectile dysfunction', 5]],
#  'An action should be seen as right or wrong through a set of rules and principles.': [['OCD',
#    0],
#   ['autism', 5],
#   ['borderline', 11],
#   ['depersonalization', 11]],
#  'Law principles should be codified into a referable system.': [['OCD', 1],
#   ['autism', 2],
#   ['mental retardation', 10],
#   ['schizoid', 11],
#   ['rumination', 10]],
#  'Courts should reference to other judicial decisions.': [['OCD', 3],
#   ['mental retardation', 3],
#   ['bipolar', 10],
#   ['dementia', 3],
#   ['postpartum depression', 8],
#   ['narcolepsy', 3],
#   ['somnambulism', 8],
#   ['restless leg syndrome', 4],
#   ['hoarding disorder', 9],
#   ['pica', 10],
#   ["Tourette's syndrome", 7],
#   ['stereotypic movement disorder', 0],
#   ['rumination', 9]],
#  'If a decision cannot be made in courts, relevant cases in the past should be referenced.': [['OCD',
#    4],
#   ['autism', 0],
#   ['dementia', 8]],
#  "Adopting radical ideas isn't possible unless compromizes are made.": [['OCD',
#    7],
#   ['bipolar', 9],
#   ['ADHD', 6],
#   ['borderline', 2],
#   ['dissociative identity disorder', 9],
#   ['avoidant personality', 6],
#   ['dependent personality disorder', 6],
#   ['conversion disorder', 1],
#   ['factitious disorder', 8],
#   ['cyclothymia', 5],
#   ['adjustment disorders', 4],
#   ['depersonalization', 6],
#   ['schizoaffective disorder', 7]],
#  'Countries with authoritarian governments should be denounced.': [['OCD', 9],
#   ['ptsd', 11],
#   ['night terrors', 6],
#   ['oppositional defiant disorder', 5],
#   ['premenstrual dysphoric disorder', 3],
#   ['tic disorders', 11]],
#  'A person cannot be moral without a religion or belief.': [['OCD', 10],
#   ['delusional disorder', 7]],
#  'We should avoid delaying political reform and change.': [['OCD', 11],
#   ['bipolar', 5],
#   ['ADHD', 11],
#   ['anorexia', 8],
#   ['erectile dysfunction', 11],
#   ['panic disorder', 1],
#   ['bulimia nervosa', 4],
#   ['seasonal affective disorder', 1],
#   ['avoidant personality', 8],
#   ['trichotillomania', 5],
#   ['pyromania', 10],
#   ['pyromania', 11],
#   ['insomnia', 7],
#   ['sleep apnea', 6],
#   ['narcolepsy', 5],
#   ['sleep paralysis', 7],
#   ['restless leg syndrome', 0],
#   ['alcoholism', 9],
#   ['gambling addiction', 7],
#   ['hoarding disorder', 3],
#   ['selective mutism', 7],
#   ['conversion disorder', 11],
#   ['rumination disorder', 10],
#   ['rumination disorder', 11],
#   ['dissociative amnesia', 8],
#   ['catatonia', 4],
#   ['tic disorders', 0],
#   ["Tourette's syndrome", 1],
#   ['binge eating', 1],
#   ['rumination', 4]],
#  'Society was better many years ago than it is today.': [['dysphoria', 0],
#   ['erectile dysfunction', 7],
#   ['dementia', 0],
#   ['seasonal affective disorder', 3],
#   ['sleep paralysis', 6],
#   ['hoarding disorder', 6],
#   ['major depressive disorder', 9],
#   ['dysthymia', 4],
#   ['dissociative amnesia', 0],
#   ['illness anxiety disorder', 11],
#   ['delusional disorder', 8],
#   ['rumination', 11]],
#  'The current mainstream societal attitudes are problematic.': [['dysphoria',
#    1],
#   ['gender dysphoria', 0],
#   ['body dysmorphic', 4],
#   ['internet addiction', 7],
#   ['self-harm', 5],
#   ['social anxiety disorder', 1],
#   ['oppositional defiant disorder', 1],
#   ['major depressive disorder', 10],
#   ['dysthymia', 9],
#   ['premenstrual dysphoric disorder', 8],
#   ['adjustment disorders', 9],
#   ['disruptive mood dysregulation', 5]],
#  'Race and ethnicity should be unimportant for everyone.': [['dysphoria', 2],
#   ['gender dysphoria', 3],
#   ['mental retardation', 11],
#   ['anorexia', 4],
#   ['dissociative identity disorder', 3],
#   ['bulimia nervosa', 5],
#   ['postpartum depression', 2],
#   ['body dysmorphic', 10],
#   ['alcoholism', 6],
#   ['body integrity identity disorder', 10],
#   ['pica', 6],
#   ['major depressive disorder', 0],
#   ['adjustment disorders', 10],
#   ['dissociative amnesia', 7],
#   ['schizophreniform disorder', 10],
#   ["Tourette's syndrome", 11]],
#  "Technology that improves mental and physical capabilities shouldn't be used, in any political system.": [['dysphoria',
#    5],
#   ['body dysmorphic', 3],
#   ['body integrity identity disorder', 2]],
#  'Monoculturalism is disastrous for society.': [['dysphoria', 7],
#   ['gender dysphoria', 11],
#   ['anorexia', 11],
#   ['intermittent explosive disorder', 11],
#   ["Tourette's syndrome", 2],
#   ['binge eating', 7]],
#  'Cultures should learn from each others to make progress quicker and easier.': [['dysphoria',
#    9],
#   ['ADHD', 10],
#   ['agoraphobia', 7],
#   ['postpartum depression', 3]],
#  'Societal progress is heading in the right direction.': [['dysphoria', 10],
#   ['Munchausen syndrome', 6],
#   ['cyclothymia', 1],
#   ['adjustment disorders', 6]],
#  'People should be treated equally regardless of their groups and characteristics.': [['gender dysphoria',
#    2],
#   ['postpartum depression', 4],
#   ['social anxiety disorder', 8]],
#  'Different countries and cultures have different preferences for the type of government.': [['gender dysphoria',
#    6],
#   ['mental retardation', 8],
#   ['ADHD', 9],
#   ['erectile dysfunction', 3],
#   ['dementia', 11],
#   ['panic disorder', 0],
#   ['generalized anxiety disorder', 7],
#   ['seasonal affective disorder', 2],
#   ['trichotillomania', 6],
#   ['somnambulism', 7],
#   ['separation anxiety disorder', 9],
#   ['pica', 4]],
#  "If the current career system is being used, a person's personal and work life should stay seperate.": [['gender dysphoria',
#    7],
#   ['borderline', 9],
#   ['dissociative identity disorder', 7],
#   ['seasonal affective disorder', 7],
#   ['insomnia', 5],
#   ['sleep apnea', 2],
#   ['alcoholism', 3],
#   ['selective mutism', 9],
#   ['separation anxiety disorder', 3],
#   ['hypochondriasis', 9],
#   ['factitious disorder', 2],
#   ['adjustment disorders', 5],
#   ['acute stress disorder', 4],
#   ['dissociative amnesia', 6],
#   ['tic disorders', 9]],
#  'Tradition is vital for society.': [['gender dysphoria', 8],
#   ['trichotillomania', 9],
#   ['conversion disorder', 8],
#   ['premenstrual dysphoric disorder', 10],
#   ['reactive attachment disorder', 7],
#   ['stereotypic movement disorder', 5]],
#  "It's important that we maintain our culture and tradition.": [['gender dysphoria',
#    9],
#   ['anorexia', 3],
#   ['erectile dysfunction', 10],
#   ['panic disorder', 8],
#   ['body dysmorphic', 7],
#   ['alcoholism', 10],
#   ['separation anxiety disorder', 4],
#   ['major depressive disorder', 2],
#   ['reactive attachment disorder', 9],
#   ['adjustment disorders', 3]],
#  'If a law system exists, lawmakers and legal experts should hold more influence than judges.': [['autism',
#    4]],
#  'Intention is more important than consequence when judging an action.': [['autism',
#    10],
#   ['kleptomania', 1],
#   ['borderline', 5]],
#  'Punishment should be valued, more than that of rehabilitation.': [['sociopathy',
#    1],
#   ['psychopathy', 2],
#   ['antisocial', 3],
#   ['conduct disorder', 8]],
#  "It's sometimes moral to crush a revolution or protest by force.": [['sociopathy',
#    3],
#   ['psychopathy', 0],
#   ['antisocial', 2]],
#  'If wages exist at all, the minimum wage should be lowered or stagnated, or even abolished.': [['sociopathy',
#    4],
#   ['psychopathy', 8]],
#  'I support capital punishment.': [['sociopathy', 5],
#   ['psychopathy', 7],
#   ['antisocial', 9]],
#  "It's a waste of time trying to rehabilitate some criminals.": [['sociopathy',
#    6],
#   ['psychopathy', 3],
#   ['antisocial', 0],
#   ['conduct disorder', 9]],
#  'Pacifism is generally unrealistic when protesting a government.': [['sociopathy',
#    8],
#   ['self-harm', 6],
#   ['disinhibited social engagement disorder', 7]],
#  'Capitalism is the most practical and realistic economic system yet.': [['sociopathy',
#    9],
#   ['ptsd', 10],
#   ['conversion disorder', 6]],
#  'A rehabilitative system is unjust.': [['sociopathy', 10],
#   ['psychopathy', 5],
#   ['antisocial', 4],
#   ['oppositional defiant disorder', 2],
#   ['conduct disorder', 6]],
#  'An eye for eye and a tooth for tooth.': [['psychopathy', 1],
#   ['ptsd', 6],
#   ['antisocial', 7],
#   ['pyromania', 0],
#   ['pyromania', 1],
#   ['restless leg syndrome', 8],
#   ['pica', 7],
#   ['conduct disorder', 3],
#   ['intermittent explosive disorder', 2],
#   ['reactive attachment disorder', 6],
#   ['tic disorders', 2],
#   ['stereotypic movement disorder', 1]],
#  'We should judge an action based on its consequences.': [['psychopathy', 9],
#   ['kleptomania', 2]],
#  "Any drug should be legal as long as other people don't have to take the consequences.": [['psychopathy',
#    10],
#   ['antisocial', 1],
#   ['alcoholism', 0],
#   ['drug addiction', 0],
#   ['gambling addiction', 10],
#   ['self-harm', 8],
#   ['conduct disorder', 7]],
#  'The Justice System should be partially privatized, or even fully privatized.': [['psychopathy',
#    11],
#   ['schizotypal', 11]],
#  'Paying workers with food is preferable than paying with money.': [['mental retardation',
#    0],
#   ['anorexia', 1],
#   ['kleptomania', 0],
#   ['dementia', 4],
#   ['bulimia nervosa', 0],
#   ['pyromania', 2],
#   ['pyromania', 3],
#   ['sleep apnea', 1],
#   ['narcolepsy', 9],
#   ['somnambulism', 3],
#   ['sleep paralysis', 2],
#   ['gambling addiction', 8],
#   ['factitious disorder', 3],
#   ['Munchausen syndrome', 1],
#   ['pica', 0],
#   ['intermittent explosive disorder', 8],
#   ['dissociative amnesia', 2],
#   ['somatic symptom disorder', 9],
#   ['tic disorders', 8],
#   ['feeding disorder', 0]],
#  'Unusual cases cannot be decided with written law.': [['mental retardation',
#    1],
#   ['anorexia', 5],
#   ['dementia', 2],
#   ['bulimia nervosa', 10],
#   ['narcolepsy', 1],
#   ['somnambulism', 4],
#   ['gambling addiction', 6],
#   ['dissociative amnesia', 11],
#   ['somatic symptom disorder', 6],
#   ['catatonia', 10]],
#  'The market should be able to provide a majority of healthcare services.': [['mental retardation',
#    4],
#   ['kleptomania', 7],
#   ['dementia', 5],
#   ['sleep apnea', 7],
#   ['somnambulism', 11],
#   ['drug addiction', 10]],
#  'A beneficial democracy requires high levels of education.': [['mental retardation',
#    5],
#   ['bipolar', 7],
#   ['dementia', 10]],
#  'Traditional medicines are often more effective than modern medicines.': [['mental retardation',
#    7],
#   ['dementia', 7],
#   ['generalized anxiety disorder', 11],
#   ['postpartum depression', 6],
#   ['trichotillomania', 4],
#   ['body dysmorphic', 2],
#   ['insomnia', 3],
#   ['somnambulism', 1],
#   ['sleep paralysis', 5],
#   ['drug addiction', 2],
#   ['conversion disorder', 9],
#   ['hypochondriasis', 0],
#   ['factitious disorder', 1],
#   ['Munchausen syndrome', 5],
#   ['pica', 1],
#   ['somatic symptom disorder', 0],
#   ['illness anxiety disorder', 0],
#   ['delusional disorder', 2],
#   ['brief psychotic disorder', 2],
#   ['tic disorders', 1],
#   ['feeding disorder', 8]],
#  'Politics is boring to me.': [['mental retardation', 9],
#   ['avoidant personality', 10],
#   ['schizoid', 0],
#   ['narcolepsy', 2],
#   ['somnambulism', 9],
#   ['alcoholism', 11],
#   ['internet addiction', 10],
#   ['selective mutism', 3],
#   ['specific phobias', 5],
#   ['intermittent explosive disorder', 4],
#   ['disinhibited social engagement disorder', 9],
#   ['dissociative amnesia', 3],
#   ['depersonalization', 5],
#   ['catatonia', 3]],
#  'Violence is not acceptable when protesting a government.': [['ptsd', 1],
#   ['restless leg syndrome', 10],
#   ['self-harm', 1],
#   ['selective mutism', 6],
#   ['conversion disorder', 2],
#   ['oppositional defiant disorder', 10],
#   ['conduct disorder', 10],
#   ['disinhibited social engagement disorder', 5],
#   ['adjustment disorders', 7],
#   ['acute stress disorder', 1],
#   ['somatic symptom disorder', 10],
#   ['disruptive mood dysregulation', 7]],
#  'The sacrifice of some civil liberties is necessary to protect us from acts of terrorism.': [['ptsd',
#    2],
#   ['panic disorder', 5],
#   ['night terrors', 1],
#   ['premenstrual dysphoric disorder', 9],
#   ['acute stress disorder', 6]],
#  'When a threat arrives, some liberties should be sacrificed in order to maintain stability and prosperity.': [['ptsd',
#    3],
#   ['panic disorder', 11],
#   ['dependent personality disorder', 8],
#   ['night terrors', 4]],
#  'Military spending is a waste of money.': [['ptsd', 4],
#   ['anorexia', 9],
#   ['generalized anxiety disorder', 8],
#   ['insomnia', 8],
#   ['specific phobias', 11],
#   ['major depressive disorder', 5],
#   ['premenstrual dysphoric disorder', 11],
#   ['tic disorders', 7],
#   ["Tourette's syndrome", 6],
#   ['disruptive mood dysregulation', 11]],
#  'Changing the status quo using violent methods is mostly unhelpful.': [['ptsd',
#    5],
#   ['antisocial', 6],
#   ['self-harm', 3],
#   ['oppositional defiant disorder', 3],
#   ['conduct disorder', 2],
#   ['intermittent explosive disorder', 9],
#   ['disinhibited social engagement disorder', 11],
#   ['disruptive mood dysregulation', 1]],
#  'All reforms should happen without violence.': [['ptsd', 7],
#   ['anorexia', 10],
#   ['bulimia nervosa', 8],
#   ['seasonal affective disorder', 9],
#   ['avoidant personality', 11],
#   ['narcolepsy', 6],
#   ['somnambulism', 5],
#   ['restless leg syndrome', 6],
#   ['self-harm', 10],
#   ['selective mutism', 2],
#   ['specific phobias', 10],
#   ['conversion disorder', 4],
#   ['factitious disorder', 7],
#   ['major depressive disorder', 6],
#   ['dysthymia', 10],
#   ['dissociative amnesia', 9],
#   ['catatonia', 11],
#   ["Tourette's syndrome", 10],
#   ['disruptive mood dysregulation', 6]],
#  'Violent action should be made to countries that violate basic human rights.': [['ptsd',
#    8],
#   ['kleptomania', 10],
#   ['bulimia nervosa', 6],
#   ['antisocial', 11],
#   ['pyromania', 4],
#   ['pyromania', 5],
#   ['restless leg syndrome', 2],
#   ['conduct disorder', 0],
#   ['intermittent explosive disorder', 0],
#   ['premenstrual dysphoric disorder', 7],
#   ['reactive attachment disorder', 10],
#   ['disinhibited social engagement disorder', 0],
#   ['disruptive mood dysregulation', 0]],
#  'We should be more optimistic towards a variety of different ideas.': [['bipolar',
#    0],
#   ['ADHD', 0],
#   ['dissociative identity disorder', 4],
#   ['bulimia nervosa', 3],
#   ['postpartum depression', 10],
#   ['seasonal affective disorder', 5],
#   ['histrionic', 11],
#   ['schizotypal', 2],
#   ['hypochondriasis', 4],
#   ['cyclothymia', 0],
#   ['schizophreniform disorder', 7],
#   ['binge eating', 2]],
#  'If the electoral college exists at all, electoral votes needs to be adjusted so that different states/regions get representation.': [['bipolar',
#    1],
#   ['postpartum depression', 9],
#   ['sleep apnea', 11],
#   ['restless leg syndrome', 11],
#   ['separation anxiety disorder', 8],
#   ['cyclothymia', 9],
#   ['schizophreniform disorder', 0],
#   ['schizoaffective disorder', 6],
#   ["Tourette's syndrome", 4]],
#  'My political ideals can be acheived within 10 years.': [['bipolar', 3],
#   ['cyclothymia', 6],
#   ['delusional disorder', 0],
#   ['brief psychotic disorder', 1]],
#  'We should not ignore ideologies that seem radical, but has a chance of success.': [['bipolar',
#    4],
#   ['schizotypal', 4],
#   ['sleep paralysis', 11],
#   ['cyclothymia', 7]],
#  'A regulated economy is more unfair for the people, when compared to a laissez-faire economy.': [['bipolar',
#    6],
#   ['schizoaffective disorder', 8]],
#  'Jury nullification should be legal.': [['bipolar', 8], ['sleep apnea', 5]],
#  'Genetic modification of food can avoid effects from droughts and floods.': [['bipolar',
#    11],
#   ['ADHD', 7],
#   ['anorexia', 6],
#   ['bulimia nervosa', 9],
#   ['trichotillomania', 10],
#   ['insomnia', 10],
#   ['gambling addiction', 2],
#   ['internet addiction', 9],
#   ['hoarding disorder', 1],
#   ['selective mutism', 10],
#   ['factitious disorder', 11],
#   ['Munchausen syndrome', 4],
#   ['pica', 3],
#   ['rumination disorder', 4],
#   ['rumination disorder', 5],
#   ['illness anxiety disorder', 6],
#   ['schizophreniform disorder', 3],
#   ['binge eating', 3],
#   ['rumination', 3],
#   ['feeding disorder', 1]],
#  'Borders around the world should be less strict.': [['ADHD', 2],
#   ['borderline', 3],
#   ['generalized anxiety disorder', 5],
#   ['drug addiction', 7],
#   ['pica', 8],
#   ['intermittent explosive disorder', 10],
#   ['adjustment disorders', 11],
#   ['schizophreniform disorder', 6],
#   ['binge eating', 6]],
#  'Everybody deserves a second chance.': [['ADHD', 4],
#   ['kleptomania', 3],
#   ['borderline', 0],
#   ['dissociative identity disorder', 5],
#   ['bulimia nervosa', 1],
#   ['seasonal affective disorder', 4],
#   ['histrionic', 3],
#   ['dependent personality disorder', 7],
#   ['trichotillomania', 7],
#   ['narcolepsy', 4],
#   ['alcoholism', 4],
#   ['drug addiction', 5],
#   ['gambling addiction', 0],
#   ['hoarding disorder', 0],
#   ['self-harm', 2],
#   ['selective mutism', 8],
#   ['intermittent explosive disorder', 1],
#   ['reactive attachment disorder', 2],
#   ['adjustment disorders', 2],
#   ['dissociative amnesia', 4],
#   ['binge eating', 0]],
#  'A free economy is the best tool for establishing wages and the price of labour.': [['ADHD',
#    8]],
#  'Being self-sufficient (as a person) is a positive trait.': [['anorexia', 2],
#   ['borderline', 8],
#   ['panic disorder', 10],
#   ['agoraphobia', 1],
#   ['histrionic', 9],
#   ['avoidant personality', 7],
#   ['dependent personality disorder', 2],
#   ['schizoid', 6],
#   ['trichotillomania', 2],
#   ['body dysmorphic', 11],
#   ['alcoholism', 2],
#   ['self-harm', 0],
#   ['hypochondriasis', 7],
#   ['binge eating', 9],
#   ['feeding disorder', 10]],
#  'Environmental activism and social pressure are a more effective way of saving the environment when compared to government action.': [['anorexia',
#    7],
#   ['bulimia nervosa', 2],
#   ['premenstrual dysphoric disorder', 6],
#   ['delusional disorder', 6],
#   ['rumination', 6]],
#  'National sovereignty is very important.': [['erectile dysfunction', 2],
#   ['kleptomania', 9],
#   ['night terrors', 9],
#   ['separation anxiety disorder', 7]],
#  'If I were to support international organizations at all, I will only support international organizations that align with my political beliefs.': [['erectile dysfunction',
#    8],
#   ['specific phobias', 7]],
#  'If we accept migrants into our borders, the migrants should be expected to assimilate into our culture.': [['erectile dysfunction',
#    9]],
#  'The market regulates itself, unjust monopolies will not survive in a free market.': [['kleptomania',
#    11],
#   ['gambling addiction', 5]],
#  'Compromizing can avoid unnecessary conflict.': [['borderline', 1],
#   ['panic disorder', 2],
#   ['agoraphobia', 4],
#   ['dissociative identity disorder', 8],
#   ['seasonal affective disorder', 11],
#   ['histrionic', 7],
#   ['avoidant personality', 1],
#   ['dependent personality disorder', 3],
#   ['self-harm', 4],
#   ['selective mutism', 11],
#   ['intermittent explosive disorder', 5],
#   ['disinhibited social engagement disorder', 4],
#   ['adjustment disorders', 0],
#   ['dissociative amnesia', 10],
#   ['depersonalization', 3],
#   ['disruptive mood dysregulation', 8]],
#  'Most things can only be accomplished through a group.': [['borderline', 6],
#   ['panic disorder', 3],
#   ['agoraphobia', 5],
#   ['dissociative identity disorder', 10],
#   ['histrionic', 0],
#   ['avoidant personality', 4],
#   ['dependent personality disorder', 1],
#   ['schizoid', 2],
#   ['body dysmorphic', 8],
#   ['alcoholism', 5],
#   ['social anxiety disorder', 0],
#   ['separation anxiety disorder', 11],
#   ['body integrity identity disorder', 7],
#   ['intermittent explosive disorder', 3],
#   ['major depressive disorder', 8],
#   ['reactive attachment disorder', 8],
#   ['acute stress disorder', 7],
#   ['depersonalization', 7],
#   ['feeding disorder', 2]],
#  'Conflict should be avoided as much as possible.': [['panic disorder', 9],
#   ['agoraphobia', 2],
#   ['histrionic', 8],
#   ['avoidant personality', 0],
#   ['dependent personality disorder', 0],
#   ['schizoid', 9],
#   ['social anxiety disorder', 2],
#   ['specific phobias', 2],
#   ['premenstrual dysphoric disorder', 5],
#   ['reactive attachment disorder', 1],
#   ['acute stress disorder', 5],
#   ['depersonalization', 4],
#   ['somatic symptom disorder', 7],
#   ['stereotypic movement disorder', 10]],
#  "Governments should stay out of the people's daily lives.": [['agoraphobia',
#    3],
#   ['drug addiction', 6],
#   ['separation anxiety disorder', 6]],
#  'Each nation should govern itself with minimal or no foreign intervention.': [['agoraphobia',
#    6],
#   ['separation anxiety disorder', 1]],
#  'Politics should be avoided in daily life.': [['agoraphobia', 8],
#   ['avoidant personality', 3],
#   ['narcolepsy', 10],
#   ['somnambulism', 10],
#   ['social anxiety disorder', 10],
#   ['selective mutism', 1],
#   ['specific phobias', 9],
#   ['conversion disorder', 5],
#   ['disinhibited social engagement disorder', 6],
#   ['dissociative amnesia', 5],
#   ['depersonalization', 1],
#   ['catatonia', 9],
#   ['tic disorders', 5]],
#  'I support Regional Unions, like the European Union.': [['agoraphobia', 9],
#   ['seasonal affective disorder', 10],
#   ['somnambulism', 2],
#   ['self-harm', 7],
#   ['separation anxiety disorder', 2],
#   ['pica', 5]],
#  'Usage of genetic modification for animals and plants should be minimized.': [['agoraphobia',
#    11],
#   ['generalized anxiety disorder', 2],
#   ['body dysmorphic', 5],
#   ['hoarding disorder', 4],
#   ['self-harm', 9],
#   ['selective mutism', 4],
#   ['specific phobias', 0],
#   ['hypochondriasis', 3],
#   ['body integrity identity disorder', 4],
#   ['Munchausen syndrome', 11],
#   ['pica', 9],
#   ['rumination disorder', 6],
#   ['rumination disorder', 7],
#   ['oppositional defiant disorder', 6],
#   ['premenstrual dysphoric disorder', 2],
#   ['somatic symptom disorder', 3],
#   ['illness anxiety disorder', 8],
#   ['tic disorders', 4],
#   ['rumination', 2],
#   ['feeding disorder', 5]],
#  'Some cultures are inherently suprerior to other cultures.': [['generalized anxiety disorder',
#    4],
#   ['specific phobias', 4]],
#  "It's important that we put aside our differences and cooperate as a single community.": [['dissociative identity disorder',
#    2],
#   ['bulimia nervosa', 11],
#   ['histrionic', 1],
#   ['schizoid', 5],
#   ['schizotypal', 5],
#   ['social anxiety disorder', 6],
#   ['body integrity identity disorder', 9],
#   ['intermittent explosive disorder', 6],
#   ['disinhibited social engagement disorder', 8],
#   ['acute stress disorder', 8],
#   ['depersonalization', 8],
#   ['schizophreniform disorder', 11],
#   ['stereotypic movement disorder', 8]],
#  'My ideology should be established as quick as possible.': [['histrionic',
#    10],
#   ['night terrors', 10],
#   ['conversion disorder', 7],
#   ['brief psychotic disorder', 0],
#   ['catatonia', 6],
#   ['stereotypic movement disorder', 11],
#   ['binge eating', 11],
#   ['feeding disorder', 3]],
#  'The existence of the state is a violation of our liberty and rights.': [['antisocial',
#    10]],
#  'Reforms should happen gradually and slowly.': [['avoidant personality', 2],
#   ['dependent personality disorder', 4],
#   ['schizoid', 3],
#   ['sleep apnea', 10],
#   ['narcolepsy', 7],
#   ['conversion disorder', 3],
#   ['hypochondriasis', 10],
#   ['dysthymia', 2],
#   ['premenstrual dysphoric disorder', 4],
#   ['reactive attachment disorder', 3],
#   ['catatonia', 2]],
#  'Many problems in society are often solved quickly and easily by a large government.': [['dependent personality disorder',
#    9],
#   ['factitious disorder', 6],
#   ['brief psychotic disorder', 6],
#   ['catatonia', 8]],
#  'Political leaders should change the system as little as possible during their term.': [['dependent personality disorder',
#    10],
#   ['reactive attachment disorder', 5]],
#  'A global nation where all countries are united will be beneficial to humanity.': [['schizotypal',
#    3],
#   ['sleep paralysis', 9],
#   ['cyclothymia', 8],
#   ['delusional disorder', 4],
#   ['brief psychotic disorder', 11]],
#  'Governmental social programs should be replaced with private charities and organizations.': [['schizotypal',
#    8],
#   ['schizoaffective disorder', 11]],
#  'Evolution is a fact.': [['trichotillomania', 11],
#   ['factitious disorder', 0],
#   ["Tourette's syndrome", 3]],
#  "Politics is very important for society, and shouldn't be ignored.": [['insomnia',
#    11],
#   ['restless leg syndrome', 7],
#   ['hoarding disorder', 8],
#   ['hypochondriasis', 2],
#   ['rumination disorder', 8],
#   ['rumination disorder', 9],
#   ['binge eating', 10],
#   ['rumination', 5]],
#  "My ideology is sometimes considered 'extreme'.": [['sleep apnea', 8],
#   ['night terrors', 8],
#   ['somatic symptom disorder', 5],
#   ['stereotypic movement disorder', 2],
#   ['feeding disorder', 11]],
#  'Taxation for the rich should be lowered, or even abolished.': [['sleep paralysis',
#    10],
#   ['factitious disorder', 10]],
#  'If a certain group has a very strong group identity, an independence referendum should be held.': [['restless leg syndrome',
#    5],
#   ['separation anxiety disorder', 0],
#   ['major depressive disorder', 11],
#   ['depersonalization', 9]],
#  'I support the Black Lives Matter organization.': [['restless leg syndrome',
#    9],
#   ['hoarding disorder', 11],
#   ['separation anxiety disorder', 10],
#   ['major depressive disorder', 7],
#   ['acute stress disorder', 3]],
#  'Freedom of business is the best practical way a society can prosper.': [['drug addiction',
#    8]],
#  'Globalization is inevitable.': [['internet addiction', 3]],
#  'Multiculturalism is unrealistic.': [['specific phobias', 3]],
#  'All authority should be questioned.': [['oppositional defiant disorder', 0],
#   ['conduct disorder', 1],
#   ['reactive attachment disorder', 11],
#   ['disruptive mood dysregulation', 2]],
#  'My political views are very different from the current status quo.': [['oppositional defiant disorder',
#    11]],
#  'If the cause is justified in my political ideology and peaceful reform does not work, revolution and aggressive measures should be considered.': [['conduct disorder',
#    5],
#   ['intermittent explosive disorder', 7],
#   ['disinhibited social engagement disorder', 2],
#   ['brief psychotic disorder', 3],
#   ['disruptive mood dysregulation', 4]],
#  'Martial law is appropiate if a nation is undergoing a crisis.': [['acute stress disorder',
#    2],
#   ['brief psychotic disorder', 9],
#   ['catatonia', 7]],
#  'Roads and transportation should be publicly owned.': [['schizophreniform disorder',
#    4],
#   ["Tourette's syndrome", 9]],
#  'Communism is an ideology that would never work in practice.': [["Tourette's syndrome",
#    8]],
#  'Only allowing scientific experts to run for an election is preferable than that of a regular democracy.': [['stereotypic movement disorder',
#    7]]}

# %%
from math import log

# %%
log(8) - log(9)

# %%
scores
# Out:
# [['A transitional state should be made.', 271],
#  ["Rapid change often leads to the worsening of people's lives.", 252],
#  ['Everybody deserves a second chance.', 186],
#  ['Paying workers with food is preferable than paying with money.', 176],
#  ['Traditional medicines are often more effective than modern medicines.',
#   175],
#  ['We should avoid delaying political reform and change.', 173],
#  ['Usage of genetic modification for animals and plants should be minimized.',
#   135],
#  ['Most things can only be accomplished through a group.', 131],
#  ['Genetic modification of food can avoid effects from droughts and floods.',
#   122],
#  ['Thinking in the long term is more important than thinking in the short term.',
#   118],
#  ['People are overly worrying about physical human modifications nowadays.',
#   116],
#  ['Compromizing can avoid unnecessary conflict.', 110],
#  ['Conflict should be avoided as much as possible.', 104],
#  ['An eye for eye and a tooth for tooth.', 100],
#  ['We should be more optimistic towards a variety of different ideas.', 96],
#  ['Being self-sufficient (as a person) is a positive trait.', 94],
#  ["If the current career system is being used, a person's personal and work life should stay seperate.",
#   93],
#  ['Violent action should be made to countries that violate basic human rights.',
#   93],
#  ['Race and ethnicity should be unimportant for everyone.', 92],
#  ['Technology is negatively affecting modern society.', 85],
#  ['Politics is boring to me.', 85],
#  ['The current mainstream societal attitudes are problematic.', 84],
#  ['The harder you work, the more you progress up the social ladder.', 82],
#  ['Transhumanism will be inevitable in the near future, in most nations.', 82],
#  ['Reforms should happen gradually and slowly.', 82],
#  ['I consider abortion as a form of murder.', 81],
#  ['All reforms should happen without violence.', 81],
#  ["Adopting radical ideas isn't possible unless compromizes are made.", 80],
#  ['Courts should reference to other judicial decisions.', 79],
#  ['Society was better many years ago than it is today.', 79],
#  ['The risks of transhumanism overweighs the benefits.', 74],
#  ['Transhumanism is not required in any country within the next 50 years.',
#   74],
#  ['Violence is not acceptable when protesting a government.', 74],
#  ['Politics should be avoided in daily life.', 74],
#  ['Different countries and cultures have different preferences for the type of government.',
#   72],
#  ['Economic inequality is still a very serious problem.', 70],
#  ["It's important that we put aside our differences and cooperate as a single community.",
#   68],
#  ['Unusual cases cannot be decided with written law.', 64],
#  ['Changing the status quo using violent methods is mostly unhelpful.', 56],
#  ["It's important that we maintain our culture and tradition.", 55],
#  ['We should embrace modern technology rather than avoiding it.', 53],
#  ["Victimless crimes should not be considered 'crimes'.", 52],
#  ['Borders around the world should be less strict.', 50],
#  ['Modernity and social progress has led to a decrease of happiness, and often lacks meaning.',
#   49],
#  ['If the electoral college exists at all, electoral votes needs to be adjusted so that different states/regions get representation.',
#   49],
#  ["Any drug should be legal as long as other people don't have to take the consequences.",
#   48],
#  ['Genetic modification of humans is beneficial.', 47],
#  ['The Industrial Revolution and its consequences have been a disaster for the human race.',
#   45],
#  ['If a person has nothing to hide, that person has nothing to fear.', 44],
#  ['The police was not made to protect the people, but to uphold the status-quo by force.',
#   44],
#  ['My nation is great.', 44],
#  ['Inheritance is a legitimate form of wealth.', 43],
#  ['Idealists are mostly unrealistic.', 43],
#  ['Military spending is a waste of money.', 40],
#  ['Nearly all politicians are evil and problematic, no matter what their political ideals are.',
#   39],
#  ['If the cause is justified in my political ideology and peaceful reform does not work, revolution and aggressive measures should be considered.',
#   39],
#  ['My political ideals can be acheived within 10 years.', 38],
#  ['My ideology should be established as quick as possible.', 38],
#  ['Traditions are of no value on their own.', 37],
#  ['The sacrifice of some civil liberties is necessary to protect us from acts of terrorism.',
#   37],
#  ['I support Regional Unions, like the European Union.', 37],
#  ['Any action that does not impose agression on any person should not be considered a criminal offence.',
#   36],
#  ['Most corporations should be state-owned.', 36],
#  ["Politics is very important for society, and shouldn't be ignored.", 36],
#  ['My political values should be spread as much as possible.', 35],
#  ['Oppression by corporations is a huge concern.', 34],
#  ['Punishment should be valued, more than that of rehabilitation.', 34],
#  ['All authority should be questioned.', 34],
#  ['Getting past physical limitations through technology would be beneficial to mankind.',
#   33],
#  ['A rehabilitative system is unjust.', 33],
#  ['Environmental activism and social pressure are a more effective way of saving the environment when compared to government action.',
#   33],
#  ['In the current system, it is necessary for the government to intervene in the economy to protect consumers.',
#   32],
#  ['I support the LGBT Community.', 31],
#  ["It's sometimes moral to crush a revolution or protest by force.", 31],
#  ['Whether or not the state is democratic, it is still oppresive.', 30],
#  ['If judges and legislators exist, judges should hold more power than legislators.',
#   30],
#  ["It's a waste of time trying to rehabilitate some criminals.", 30],
#  ['Without state intervention, monopolies would violate human rights.', 28],
#  ['If taxation exists, churches should be taxed the same way other institutions are taxed.',
#   28],
#  ['The market should be able to provide a majority of healthcare services.',
#   28],
#  ['Countries with authoritarian governments should be denounced.', 27],
#  ['Even though equal opportunities can lead to equal outcomes, society should still focus on equal opportunities, and not equal outcomes.',
#   26],
#  ['Law principles should be codified into a referable system.', 26],
#  ["Technology that improves mental and physical capabilities shouldn't be used, in any political system.",
#   26],
#  ["My ideology is sometimes considered 'extreme'.", 26],
#  ['Societal progress is heading in the right direction.', 25],
#  ['Tradition is vital for society.', 25],
#  ['A global nation where all countries are united will be beneficial to humanity.',
#   25],
#  ['If a decision cannot be made in courts, relevant cases in the past should be referenced.',
#   24],
#  ['Monoculturalism is disastrous for society.', 23],
#  ['If a certain group has a very strong group identity, an independence referendum should be held.',
#   23],
#  ['The means of production should belong to the workers.', 22],
#  ['People should be treated equally regardless of their groups and characteristics.',
#   22],
#  ['When a threat arrives, some liberties should be sacrificed in order to maintain stability and prosperity.',
#   22],
#  ['We should not ignore ideologies that seem radical, but has a chance of success.',
#   22],
#  ['Evolution is a fact.', 22],
#  ['A system of equal outcomes should be established.', 21],
#  ['An action should be seen as right or wrong through a set of rules and principles.',
#   21],
#  ['National sovereignty is very important.', 21],
#  ["Governments should stay out of the people's daily lives.", 21],
#  ['If artifical intellegence can rule better than humans, then they should rule.',
#   20],
#  ['My nation should be more diverse.', 20],
#  ['Intention is more important than consequence when judging an action.', 20],
#  ['I support the Black Lives Matter organization.', 20],
#  ['Compromises should be made in order to suit the needs of most people.', 19],
#  ['Liberal democracy is the least worst system for leadership.', 19],
#  ['Cultures should learn from each others to make progress quicker and easier.',
#   19],
#  ['Many problems in society are often solved quickly and easily by a large government.',
#   19],
#  ['All countries should solve its internal issues before focusing on external issues.',
#   18],
#  ['A global organization that is generally beneficial should hold a substantial amount of power.',
#   18],
#  ["It's a good thing that Nationalism is on the rise.", 18],
#  ['Martial law is appropiate if a nation is undergoing a crisis.', 18],
#  ['From each according to his ability, to each according to his needs.', 17],
#  ['Each nation should govern itself with minimal or no foreign intervention.',
#   17],
#  ['Any well-functioning society requries a hierarchy.', 16],
#  ['Some cultures are inherently suprerior to other cultures.', 16],
#  ["My nation's interests should be considered more important than that of other nations.",
#   15],
#  ['I support capital punishment.', 15],
#  ['Pacifism is generally unrealistic when protesting a government.', 15],
#  ['A beneficial democracy requires high levels of education.', 14],
#  ['Private organisations and corporations cannot be trusted and thus need regulating by the government.',
#   13],
#  ['Religion is mostly fictional.', 13],
#  ['We should judge an action based on its consequences.', 13],
#  ['If wages exist at all, the minimum wage should be lowered or stagnated, or even abolished.',
#   12],
#  ['The current political system in my nation is flawed.', 11],
#  ['Capitalism is the most practical and realistic economic system yet.', 11],
#  ['Jury nullification should be legal.', 11],
#  ['Roads and transportation should be publicly owned.', 11],
#  ['A regulated economy is more unfair for the people, when compared to a laissez-faire economy.',
#   10],
#  ['If I were to support international organizations at all, I will only support international organizations that align with my political beliefs.',
#   9],
#  ['Political leaders should change the system as little as possible during their term.',
#   9],
#  ['Globalization is inevitable.', 9],
#  ['Multiculturalism is unrealistic.', 9],
#  ['Automation is very beneficial for society.', 8],
#  ['If a law system exists, lawmakers and legal experts should hold more influence than judges.',
#   8],
#  ['The market regulates itself, unjust monopolies will not survive in a free market.',
#   8],
#  ['A person cannot be moral without a religion or belief.', 7],
#  ['Hierarchies will inevitably be formed in every society, at any time.', 6],
#  ['Governmental social programs should be replaced with private charities and organizations.',
#   5],
#  ['Only allowing scientific experts to run for an election is preferable than that of a regular democracy.',
#   5],
#  ['Democracy increases the risks of instability and corruption.', 4],
#  ['A free economy is the best tool for establishing wages and the price of labour.',
#   4],
#  ['Taxation for the rich should be lowered, or even abolished.', 4],
#  ['Freedom of business is the best practical way a society can prosper.', 4],
#  ['Communism is an ideology that would never work in practice.', 4],
#  ['If we accept migrants into our borders, the migrants should be expected to assimilate into our culture.',
#   3],
#  ['The Justice System should be partially privatized, or even fully privatized.',
#   2],
#  ['The existence of the state is a violation of our liberty and rights.', 2],
#  ['An autocracy is more beneficial than any democratic system.', 1],
#  ['My political views are very different from the current status quo.', 1]]

# %%
scores = []
for t in top_issues:
    arr = top_issues[t]
    score = 0
    for a in arr:
        score += (12 - a[1])
    scores.append([t, score])
    
scores.sort(key=lambda x:x[1], reverse=True)

total_effects = {}
for s in scores[1:]:
    #print(s[0], s[1])
    q = quest_map[s[0]]
    #print(q)
    for e in q['effects']:
        if e not in total_effects:
            total_effects[e] = 0
        total_effects[e] += abs(q['effects'][e])*ae_bias[e]*s[1]

tups = []
for t in total_effects:
    tups.append([t, total_effects[t]])
tups.sort(key=lambda x:x[1], reverse=True)

for t in tups:
    print(notation[t[0]], t[1])
# Out:
# ['morality', 'individualism/collectivism'] 16430.0
# ['society', 'conserve/reform'] 13708.888888888889
# ['procedure', 'persist/compromize'] 10798.333333333334
# ['technology', 'primitivism/transhumanism'] 10462.5
# ['technology', 'decelerate/accelerate'] 9412.727272727274
# ['law', 'punitive/rehabilatative'] 9238.0
# ['politics', 'radical/moderate'] 9067.5
# ['morality', 'idealism/realism'] 8318.333333333334
# ['diplomacy', 'particular/universal'] 7304.375
# ['society', 'tradition/progress'] 6960.909090909092
# ['law', 'civil/common'] 5967.500000000001
# ['morality', 'consequential/deontologic'] 5967.5
# ['morality', 'revolution/peaceful'] 5502.5
# ['economy', 'left/right'] 5134.375
# ['economy', 'capitalism/socialism'] 5134.375
# ['government', 'autocracy/democracy'] 4786.764705882351
# ['diplomacy', 'globalism/nationalism'] 4590.384615384616
# ['politics', 'politicized/apoliticized'] 4301.25
# ['culture', 'multicultural/monocultural'] 4210.833333333335
# ['procedure', 'direct/transitional'] 3926.666666666667
# ['government', 'authoritarian/libertarian'] 3715.0
# ['culture', 'hierarchy/equality'] 2821.0
# ['economy', 'free/planned'] 2441.25
# ['government', 'libertarian/authoritarian'] 2376.666666666667

# %%
from selenium import webdriver

# %%
from IPython.core.display import display, HTML
import imgkit
import time

colors = {
    'economy': 'rgb(158,1,66)',
    'government': 'rgb(213,62,79)',
    'diplomacy': 'rgb(244,109,67)',
    'society': 'rgb(253,174,97)',
    'technology': 'rgb(254,224,139)',
    'law': 'rgb(230,245,152)',
    'culture': 'rgb(171,221,164)',
    'procedure': 'rgb(102,194,165)',
    'politics': 'rgb(50,136,189)',
    'morality': 'rgb(94,79,162)'
}

def display_results(disorder, save=False, render=True):
    vals = data[disorder]
    
    html = """
        <div>
            <h1 style="font-family:system-ui;font-size:30px">{0}</h1>
            <div style="margin:20px;background:white;padding:10px;height:400px;position:relative">
    """.format(disorder[0].upper()+disorder[1:])
    
    tups = [[notation[n], vals[0][n]] for n in notation]
    tups.sort(key=lambda x:x[1], reverse=True)
    
    top = 100
    for t in tups:
        width = t[1]*1000
        
        html += """
                 <div style="display:flex; margin-left:0px">
                     <div style="
                         line-height:18px;
                         width:220px;
                         font-size:15px;
                         margin-top:6px;
                         text-align:right;
                         margin-right:5px
                         ">{0}</div>
                         
                     <div style="
                         border-radius:1px;
                         background:{3}; 
                         border:1px solid black;
                         width:{2}px;
                         height:30px;
                         "></div>
                     
                 </div>
                """.format(t[0][1], top, width, colors[t[0][0]])
        top += 80
    

               
    html += """</div>
                <div style="position:absolute;top:120px;left:330px;margin:40px;width:500px;font-size:16px; color:rgb(120, 153, 34)">
                    <!-- <div id='methodology'>
                    <div style='color: rgb(40,40,40);;font-weight:bold'>Methodology</div>
                        <p style="margin-top:0px; color:rgb(100 100 100)">
                            The <span style='color:rgb(70 140 201)'>10groups</span> question set was ran through <span style='color:rgb(70 140 201)'>Llama-2-70b-hf</span> model to get a prediction on how likely the statement would correlate with the mental disorder on the top left. 
                            From this we were able to get a fixation score.
                            For more details visit: <span style='color:rgb(70 140 201)'>mental.meaning.io</span>
                        </p>
                    </div> -->
                    <br/><br/>
                    <div id='statements'>
                        <div style='color: rgb(40,40,40);;font-weight:bold'>Statements with the highest fixation (not agreement):</div>
                        <div style='margin-left:0px'>
                            <div> > {0} </div>
                            <div> > {1} </div>
                            <div> > {2} </div>
                            <div> > {3} </div>
                            <div> > {4} </div>
                            <div> > {5} </div>
                            <div> > {6} </div>
                            <div> > {7} </div>
                            <div> > {8} </div>
                            <div> > {9} </div>
                            <div> > {10} </div>
                            <div> > {11} </div>
                        </div>
                    </div>
                    <br/><br/>
                    <div>
                        <div style="color:black; font-weight:bold">Color Reference:</div>
            """.format(*vals[2])
    
    for c in colors:
        html += """
            <span style='background:{1}; color:black; padding:4px 4px;line-height: 36px;'>{0}</span>
        """.format(c, colors[c])
    
    html +="""
                    </div>
                </div>
            </div>
        </div>"""
    if save:
        #driver = webdriver.Chrome()
        #driver.set_window_size(900, 1000)
        extra = "<html><body style=\"overflow: hidden;\">"+html.replace("right: 280px;","left: 300px;")+"</body></html>"
        #driver.get("data:text/html;charset=utf-8,{html_content}".format(html_content=extra))
        #time.sleep(1)
        #driver.save_screenshot('10group_outputs/dsm5_extra/'+disorder+'.png')
        #driver.quit()
        
        outfile = open("../LLMCompass/local-site/public/dsm5/"+disorder.replace("/","_")+".html", 'w')
        outfile.write(extra)
        outfile.close()
        
    if render:
        display(HTML(html))


display_results("gender dysphoria", save=True, render=False)

# %%
for d in disorders:
    display_results(d, save=True, render=False)
    #time.sleep(1)
    #print(d)
